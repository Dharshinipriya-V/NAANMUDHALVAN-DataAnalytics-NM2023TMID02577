# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Loading the dataset

# %%
data = pd.read_csv('House Price India.csv')

# %%
data.head(5)
# Out:
#            id   Date  number of bedrooms  number of bathrooms  living area  \
# 0  6762810145  42491                   5                 2.50         3650
# 1  6762810635  42491                   4                 2.50         2920
# 2  6762810998  42491                   5                 2.75         2910
# 3  6762812605  42491                   4                 2.50         3310
# 4  6762812919  42491                   3                 2.00         2710
#
#    lot area  number of floors  waterfront present  number of views  \
# 0      9050               2.0                   0                4
# 1      4000               1.5                   0                0
# 2      9480               1.5                   0                0
# 3     42998               2.0                   0                0
# 4      4500               1.5                   0                0
#
#    condition of the house  ...  Built Year  Renovation Year  Postal Code  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14620 entries, 0 to 14619
# Data columns (total 23 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   id                                     14620 non-null  int64
#  1   Date                                   14620 non-null  int64
#  2   number of bedrooms                     14620 non-null  int64
#  3   number of bathrooms                    14620 non-null  float64
#  4   living area                            14620 non-null  int64
#  5   lot area                               14620 non-null  int64
#  6   number of floors                       14620 non-null  float64
#  7   waterfront present                     14620 non-null  int64
#  8   number of views                        14620 non-null  int64
#  9   condition of the house                 14620 non-null  int64
# ...

# %% [markdown]
# # Univariate analysis

# %% [markdown]
# Histogram

# %%
plt.hist(data['number of bedrooms'],bins=50)
plt.xlabel("No.of.Bedrooms")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# From the above graph we can clearly see that the peek count above 6000 is at range between 0 to 5. As the no.of.bedrooms increases after 5 the count values decreases tremendously

# %% [markdown]
# Distplot

# %%
sns.distplot(data['Built Year'],bins=30)
# Out:
# <ipython-input-23-de7c8a550359>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Built Year'],bins=30)
# <Axes: xlabel='Built Year', ylabel='Density'>

# %% [markdown]
# From the above distplot we came to know that the the number of building built is peek at peek between 2000 and 2020 related to density of the distribution

# %% [markdown]
# Boxplot

# %%
sns.boxplot(data['Built Year'])
# Out:
# <Axes: >

# %% [markdown]
# Boxplot is used for detect the outlier in data set. It captures the summary of the data efficiently with a simple box and whiskers and allows us to compare easily across groups. Boxplot for built year and it contains many outliers and many outliers present in the features. The above one is a sample for detecting outliers.

# %% [markdown]
# Violinplot

# %%
sns.violinplot(x=data['number of views'])
# Out:
# <Axes: xlabel='number of views'>

# %% [markdown]
# violinplot is used to vizualize the distribution numerical data and it shows the full distribution of data. The mean value of the variable "number of views" lies in 0 and the interquartile ranges between 1 to 4. The rest thin lines represents the rest distributions, except for the points that are determined to be the outliers. The higher probability lies in 3 and lowest probability lies above 5.

# %% [markdown]
# Piechart

# %% [markdown]
# A piechart helps us to visualize the percentage of the data belonging to each category.

# %%
x = data['Number of schools nearby'].value_counts()
""""plt.pie(x.values,
        labels=x.index,
        autopct='%1.1f%%')
plt.show()"""

# %% [markdown]
# Here the piechart is derived for no.of.schools nearby for each row in the dataset.

# %% [markdown]
# # Bivariate Analysis

# %% [markdown]
# Scatterplot

# %%
sns.scatterplot(x=data['number of bedrooms'],y=data['number of bathrooms'])
# Out:
# <Axes: xlabel='number of bedrooms', ylabel='number of bathrooms'>

# %% [markdown]
# The scatterplot is used to show distributions between two variables. For no.of.bathrooms and no.of.bedrooms as far as the bathroom increases the bedroom number increases. And there are some outliers present in them.

# %% [markdown]
# Jointplot

# %%
sns.jointplot(data = data,x = 'lot area',y = 'living area')

# %% [markdown]
# The relation between living area vs lot area and univariate of these has been shown. As far as the living area increases the lot area increases slighter and present many outliers between them. Univariate distribution of lot area remains same with slight increase in area but for living area the peak value is achieved at 2000 by gradual increase in it and then decreases until at a range of 5000.

# %% [markdown]
# Line plot

# %%
plt.plot(data['Area of the basement'],data['Area of the house(excluding basement)'])

# %% [markdown]
# # Multivariate Analysis

# %% [markdown]
# Pairplot

# %%
Y = data[['number of bathrooms','number of bedrooms','lot area','Price','living area']]
Y
sns.pairplot(Y,dropna=True)

# %% [markdown]
# From pairplot we can clearly see that some variable are linear to some variable and logistic to some variables. Most of the variables are linear to other variables. But in all variables outliers present in it.

# %% [markdown]
# Heatmap

# %%
data.drop(columns=['id','Date'],inplace=True)
sns.heatmap(data.corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# A heat map to check the correlation between all the columns in the dataset.

# %% [markdown]
# # Descriptive statistics

# %%
data.describe()
# Out:
#                  id          Date  number of bedrooms  number of bathrooms  \
# count  1.462000e+04  14620.000000        14620.000000         14620.000000
# mean   6.762821e+09  42604.538646            3.379343             2.129583
# std    6.237575e+03     67.347991            0.938719             0.769934
# min    6.762810e+09  42491.000000            1.000000             0.500000
# 25%    6.762815e+09  42546.000000            3.000000             1.750000
# 50%    6.762821e+09  42600.000000            3.000000             2.250000
# 75%    6.762826e+09  42662.000000            4.000000             2.500000
# max    6.762832e+09  42734.000000           33.000000             8.000000
#
#         living area      lot area  number of floors  waterfront present  \
# count  14620.000000  1.462000e+04      14620.000000        14620.000000
# mean    2098.262996  1.509328e+04          1.502360            0.007661
# std      928.275721  3.791962e+04          0.540239            0.087193
# ...

# %% [markdown]
# Descriptive statistics summarize the data by computing mean, median, mode, standard deviation and likewise.

# %% [markdown]
# # Handle the Missing values

# %%
data.isnull().sum()
# Out:
# id                                       0
# Date                                     0
# number of bedrooms                       0
# number of bathrooms                      0
# living area                              0
# lot area                                 0
# number of floors                         0
# waterfront present                       0
# number of views                          0
# condition of the house                   0
# grade of the house                       0
# Area of the house(excluding basement)    0
# Area of the basement                     0
# Built Year                               0
# Renovation Year                          0
# Postal Code                              0
# Lattitude                                0
# Longitude                                0
# living_area_renov                        0
# lot_area_renov                           0
# Number of schools nearby                 0
# Distance from the airport                0
# ...

# %% [markdown]
# From the above information we can get to know that there is not null values present the dataset, so we dont want to do some specific operations to handle these null values.
